# %%
import cityflow
import math
import pandas as pd
import os
import argparse
import json

def args_parser():
    parser = argparse.ArgumentParser()
    parser.add_argument('--scenario', type=str)
    
    #训练参数
    parser.add_argument('--max_episode', type=int, default=5000)
    parser.add_argument('--max_step', type=int, default=200)
    parser.add_argument('--max_buffer', type=int, default=10000)
    parser.add_argument('--max_total_reward', type=float)

    args = parser.parse_args(args=[])
    return args

# %%
args = args_parser()
args.scenario = 'hangzhou_1x1_bc-tyc_18041607_1h'
num_step = args.max_step

# %%
import pandas as pd
import os

class CityFlowEnv():
    '''
    Simulator Environment with CityFlow
    '''
    def __init__(self, args):
        self.eng = cityflow.Engine(config_file='examples/config_control.json', thread_num=1)
#         self.eng.load_roadnet(config['roadnet'])
#         self.eng.load_flow(config['flow'])
#         self.config = config
        self.num_step = args.max_step
        self.lane_phase_info = self.parse_roadnet('examples/roadnet.json') # "intersection_1_1"

        self.intersection_id = list(self.lane_phase_info.keys())[0]
        self.start_lane = self.lane_phase_info[self.intersection_id]['start_lane']
        self.phase_list = self.lane_phase_info[self.intersection_id]["phase"]
        self.phase_startLane_mapping = self.lane_phase_info[self.intersection_id]["phase_startLane_mapping"]

        self.current_phase = self.phase_list[0]
        self.current_phase_time = 0
        self.yellow_time = 5

        self.phase_log = []

    def parse_roadnet(self, roadnetFile):
        roadnet = json.load(open(roadnetFile))
        lane_phase_info_dict ={}

        # many intersections exist in the roadnet and virtual intersection is controlled by signal
        for intersection in roadnet["intersections"]:
            if intersection['virtual']:
                continue
            lane_phase_info_dict[intersection['id']] = {"start_lane": [],
                                                         "end_lane": [],
                                                         "phase": [],
                                                         "phase_startLane_mapping": {},
                                                         "phase_roadLink_mapping": {}}
            road_links = intersection["roadLinks"]

            start_lane = []
            end_lane = []
            roadLink_lane_pair = {ri: [] for ri in
                                  range(len(road_links))}  # roadLink includes some lane_pair: (start_lane, end_lane)

            for ri in range(len(road_links)):
                road_link = road_links[ri]
                for lane_link in road_link["laneLinks"]:
                    sl = road_link['startRoad'] + "_" + str(lane_link["startLaneIndex"])
                    el = road_link['endRoad'] + "_" + str(lane_link["endLaneIndex"])
                    start_lane.append(sl)
                    end_lane.append(el)
                    roadLink_lane_pair[ri].append((sl, el))

            lane_phase_info_dict[intersection['id']]["start_lane"] = sorted(list(set(start_lane)))
            lane_phase_info_dict[intersection['id']]["end_lane"] = sorted(list(set(end_lane)))

            for phase_i in range(1, len(intersection["trafficLight"]["lightphases"])):
                p = intersection["trafficLight"]["lightphases"][phase_i]
                lane_pair = []
                start_lane = []
                for ri in p["availableRoadLinks"]:
                    lane_pair.extend(roadLink_lane_pair[ri])
                    if roadLink_lane_pair[ri][0][0] not in start_lane:
                        start_lane.append(roadLink_lane_pair[ri][0][0])
                lane_phase_info_dict[intersection['id']]["phase"].append(phase_i)
                lane_phase_info_dict[intersection['id']]["phase_startLane_mapping"][phase_i] = start_lane
                lane_phase_info_dict[intersection['id']]["phase_roadLink_mapping"][phase_i] = lane_pair

        return lane_phase_info_dict
    
    def reset(self):
        self.eng.reset()
        self.phase_log = []

    def step(self, next_phase):
        if self.current_phase == next_phase:
            self.current_phase_time += 1
        else:
            self.current_phase = next_phase
            self.current_phase_time = 1

        self.eng.set_tl_phase(self.intersection_id, self.current_phase)
        self.eng.next_step()
        self.phase_log.append(self.current_phase)

    def get_state(self):
        state = {}
        state['lane_vehicle_count'] = self.eng.get_lane_vehicle_count()  # {lane_id: lane_count, ...}
        state['start_lane_vehicle_count'] = {lane: self.eng.get_lane_vehicle_count()[lane] for lane in self.start_lane}
        state['lane_waiting_vehicle_count'] = self.eng.get_lane_waiting_vehicle_count()  # {lane_id: lane_waiting_count, ...}
        state['lane_vehicles'] = self.eng.get_lane_vehicles()  # {lane_id: [vehicle1_id, vehicle2_id, ...], ...}
        state['vehicle_speed'] = self.eng.get_vehicle_speed()  # {vehicle_id: vehicle_speed, ...}
        state['vehicle_distance'] = self.eng.get_vehicle_distance() # {vehicle_id: distance, ...}
        state['current_time'] = self.eng.get_current_time()
        state['current_phase'] = self.current_phase
        state['current_phase_time'] = self.current_phase_time

        return state

    def get_reward(self):
        # a sample reward function which calculates the total of waiting vehicles
        lane_waiting_vehicle_count = self.eng.get_lane_waiting_vehicle_count()
        reward = -1 * sum(list(lane_waiting_vehicle_count.values()))
        return reward

    def log(self):
        #self.eng.print_log(self.config['replay_data_path'] + "/replay_roadnet.json",
        #                   self.config['replay_data_path'] + "/replay_flow.json")
        df = pd.DataFrame({self.intersection_id: self.phase_log[:self.num_step]})
#         if not os.path.exists(''):
#             os.makedirs('')
        df.to_csv(os.path.join('examples', 'signal_plan_template.txt'), index=None)

# %%
class SOTLAgent():
    ''' Agent using Fixed-time algorithm to control traffic signal
        '''

    def __init__(self, args):
        self.args = args
        self.lane_phase_info = self.parse_roadnet('examples/roadnet.json') # "intersection_1_1"

        self.intersection_id = list(self.lane_phase_info.keys())[0]
        self.start_lane = self.lane_phase_info[self.intersection_id]['start_lane']
        self.phase_list = self.lane_phase_info[self.intersection_id]["phase"]
        self.phase_startLane_mapping = self.lane_phase_info[self.intersection_id]["phase_startLane_mapping"]
        
        self.phi = 20
        self.min_green_vehicle = 20
        self.max_red_vehicle = 30

        self.action = self.phase_list[0]

    def choose_action(self, state):
        cur_phase = state["current_phase"]
        if state["current_phase_time"] >= self.phi:
            num_green_vehicle = sum([state["lane_waiting_vehicle_count"][i] for i in self.phase_startLane_mapping[cur_phase]])
            num_red_vehicle = sum([state["lane_waiting_vehicle_count"][i] for i in self.lane_phase_info[self.intersection_id]["start_lane"]]) - num_green_vehicle
            if num_green_vehicle <= self.min_green_vehicle and num_red_vehicle > self.max_red_vehicle:
                self.action = cur_phase % len(self.phase_list) + 1
        return self.action
    
    def parse_roadnet(self, roadnetFile):
        roadnet = json.load(open(roadnetFile))
        lane_phase_info_dict ={}

        # many intersections exist in the roadnet and virtual intersection is controlled by signal
        for intersection in roadnet["intersections"]:
            if intersection['virtual']:
                continue
            lane_phase_info_dict[intersection['id']] = {"start_lane": [],
                                                         "end_lane": [],
                                                         "phase": [],
                                                         "phase_startLane_mapping": {},
                                                         "phase_roadLink_mapping": {}}
            road_links = intersection["roadLinks"]

            start_lane = []
            end_lane = []
            roadLink_lane_pair = {ri: [] for ri in
                                  range(len(road_links))}  # roadLink includes some lane_pair: (start_lane, end_lane)

            for ri in range(len(road_links)):
                road_link = road_links[ri]
                for lane_link in road_link["laneLinks"]:
                    sl = road_link['startRoad'] + "_" + str(lane_link["startLaneIndex"])
                    el = road_link['endRoad'] + "_" + str(lane_link["endLaneIndex"])
                    start_lane.append(sl)
                    end_lane.append(el)
                    roadLink_lane_pair[ri].append((sl, el))

            lane_phase_info_dict[intersection['id']]["start_lane"] = sorted(list(set(start_lane)))
            lane_phase_info_dict[intersection['id']]["end_lane"] = sorted(list(set(end_lane)))

            for phase_i in range(1, len(intersection["trafficLight"]["lightphases"])):
                p = intersection["trafficLight"]["lightphases"][phase_i]
                lane_pair = []
                start_lane = []
                for ri in p["availableRoadLinks"]:
                    lane_pair.extend(roadLink_lane_pair[ri])
                    if roadLink_lane_pair[ri][0][0] not in start_lane:
                        start_lane.append(roadLink_lane_pair[ri][0][0])
                lane_phase_info_dict[intersection['id']]["phase"].append(phase_i)
                lane_phase_info_dict[intersection['id']]["phase_startLane_mapping"][phase_i] = start_lane
                lane_phase_info_dict[intersection['id']]["phase_roadLink_mapping"][phase_i] = lane_pair

        return lane_phase_info_dict

# %%
env = CityFlowEnv(args)
agent = SOTLAgent(args)

# %%
# reset initially
t = 0
env.reset()
last_action = agent.choose_action(env.get_state())

while t < args.max_step:
    state = env.get_state()
    action = agent.choose_action(state)
    if action == last_action:
        env.step(action)
    else:
        for _ in range(env.yellow_time):
            env.step(0)  # required yellow time
            t += 1
            flag = (t >= args.max_step)
            if flag:
                break
        if flag:
            break
        env.step(action)
    last_action = action
    t += 1
    print("Time: {}, Phase: {}, lane_vehicle_count: {}".format(state['current_time'], state['current_phase'],
                                                                       state['lane_vehicle_count']))

# log environment files
env.log()
# Out:
# Time: 0.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 0, 'road_0_1_0_2': 0, 'road_0_1_0_3': 0, 'road_0_1_0_4': 0, 'road_0_1_0_5': 0, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 0, 'road_1_0_1_2': 0, 'road_1_0_1_3': 0, 'road_1_0_1_4': 0, 'road_1_0_1_5': 0, 'road_1_0_1_6': 0, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 0, 'road_1_2_3_2': 0, 'road_1_2_3_3': 0, 'road_1_2_3_4': 0, 'road_1_2_3_5': 0, 'road_1_2_3_6': 0, 'road_2_1_2_0': 0, 'road_2_1_2_1': 0, 'road_2_1_2_2': 0, 'road_2_1_2_3': 0, 'road_2_1_2_4': 0, 'road_2_1_2_5': 0, 'road_2_1_2_6': 0}
# Time: 1.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 1, 'road_0_1_0_2': 0, 'road_0_1_0_3': 0, 'road_0_1_0_4': 1, 'road_0_1_0_5': 1, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 1, 'road_1_0_1_2': 0, 'road_1_0_1_3': 0, 'road_1_0_1_4': 1, 'road_1_0_1_5': 0, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 1, 'road_1_2_3_2': 1, 'road_1_2_3_3': 0, 'road_1_2_3_4': 0, 'road_1_2_3_5': 0, 'road_1_2_3_6': 1, 'road_2_1_2_0': 1, 'road_2_1_2_1': 0, 'road_2_1_2_2': 0, 'road_2_1_2_3': 1, 'road_2_1_2_4': 0, 'road_2_1_2_5': 0, 'road_2_1_2_6': 1}
# Time: 2.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 1, 'road_0_1_0_2': 0, 'road_0_1_0_3': 0, 'road_0_1_0_4': 1, 'road_0_1_0_5': 1, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 1, 'road_1_0_1_2': 0, 'road_1_0_1_3': 0, 'road_1_0_1_4': 1, 'road_1_0_1_5': 0, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 1, 'road_1_2_3_2': 1, 'road_1_2_3_3': 0, 'road_1_2_3_4': 0, 'road_1_2_3_5': 0, 'road_1_2_3_6': 1, 'road_2_1_2_0': 1, 'road_2_1_2_1': 0, 'road_2_1_2_2': 0, 'road_2_1_2_3': 1, 'road_2_1_2_4': 0, 'road_2_1_2_5': 0, 'road_2_1_2_6': 1}
# Time: 3.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 1, 'road_0_1_0_2': 0, 'road_0_1_0_3': 0, 'road_0_1_0_4': 1, 'road_0_1_0_5': 1, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 1, 'road_1_0_1_2': 0, 'road_1_0_1_3': 0, 'road_1_0_1_4': 1, 'road_1_0_1_5': 0, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 1, 'road_1_2_3_2': 1, 'road_1_2_3_3': 0, 'road_1_2_3_4': 0, 'road_1_2_3_5': 0, 'road_1_2_3_6': 1, 'road_2_1_2_0': 1, 'road_2_1_2_1': 0, 'road_2_1_2_2': 0, 'road_2_1_2_3': 1, 'road_2_1_2_4': 0, 'road_2_1_2_5': 0, 'road_2_1_2_6': 1}
# Time: 4.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 1, 'road_0_1_0_2': 0, 'road_0_1_0_3': 0, 'road_0_1_0_4': 1, 'road_0_1_0_5': 1, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 1, 'road_1_0_1_2': 0, 'road_1_0_1_3': 0, 'road_1_0_1_4': 1, 'road_1_0_1_5': 0, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 1, 'road_1_2_3_2': 1, 'road_1_2_3_3': 0, 'road_1_2_3_4': 0, 'road_1_2_3_5': 0, 'road_1_2_3_6': 1, 'road_2_1_2_0': 1, 'road_2_1_2_1': 0, 'road_2_1_2_2': 0, 'road_2_1_2_3': 1, 'road_2_1_2_4': 0, 'road_2_1_2_5': 0, 'road_2_1_2_6': 1}
# Time: 5.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 1, 'road_0_1_0_2': 0, 'road_0_1_0_3': 0, 'road_0_1_0_4': 1, 'road_0_1_0_5': 1, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 1, 'road_1_0_1_2': 0, 'road_1_0_1_3': 0, 'road_1_0_1_4': 1, 'road_1_0_1_5': 0, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 1, 'road_1_2_3_2': 1, 'road_1_2_3_3': 0, 'road_1_2_3_4': 0, 'road_1_2_3_5': 0, 'road_1_2_3_6': 1, 'road_2_1_2_0': 1, 'road_2_1_2_1': 0, 'road_2_1_2_2': 0, 'road_2_1_2_3': 1, 'road_2_1_2_4': 0, 'road_2_1_2_5': 0, 'road_2_1_2_6': 1}
# Time: 6.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 2, 'road_0_1_0_2': 1, 'road_0_1_0_3': 0, 'road_0_1_0_4': 1, 'road_0_1_0_5': 2, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 2, 'road_1_0_1_2': 0, 'road_1_0_1_3': 1, 'road_1_0_1_4': 1, 'road_1_0_1_5': 1, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 2, 'road_1_2_3_2': 1, 'road_1_2_3_3': 1, 'road_1_2_3_4': 0, 'road_1_2_3_5': 0, 'road_1_2_3_6': 2, 'road_2_1_2_0': 2, 'road_2_1_2_1': 0, 'road_2_1_2_2': 0, 'road_2_1_2_3': 2, 'road_2_1_2_4': 0, 'road_2_1_2_5': 1, 'road_2_1_2_6': 1}
# Time: 7.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 2, 'road_0_1_0_2': 1, 'road_0_1_0_3': 0, 'road_0_1_0_4': 1, 'road_0_1_0_5': 2, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 2, 'road_1_0_1_2': 0, 'road_1_0_1_3': 1, 'road_1_0_1_4': 1, 'road_1_0_1_5': 1, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 2, 'road_1_2_3_2': 1, 'road_1_2_3_3': 1, 'road_1_2_3_4': 0, 'road_1_2_3_5': 0, 'road_1_2_3_6': 2, 'road_2_1_2_0': 2, 'road_2_1_2_1': 0, 'road_2_1_2_2': 0, 'road_2_1_2_3': 2, 'road_2_1_2_4': 0, 'road_2_1_2_5': 1, 'road_2_1_2_6': 1}
# Time: 8.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 2, 'road_0_1_0_2': 1, 'road_0_1_0_3': 0, 'road_0_1_0_4': 1, 'road_0_1_0_5': 2, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 2, 'road_1_0_1_2': 0, 'road_1_0_1_3': 1, 'road_1_0_1_4': 1, 'road_1_0_1_5': 1, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 2, 'road_1_2_3_2': 1, 'road_1_2_3_3': 1, 'road_1_2_3_4': 0, 'road_1_2_3_5': 0, 'road_1_2_3_6': 2, 'road_2_1_2_0': 2, 'road_2_1_2_1': 0, 'road_2_1_2_2': 0, 'road_2_1_2_3': 2, 'road_2_1_2_4': 0, 'road_2_1_2_5': 1, 'road_2_1_2_6': 1}
# Time: 9.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 2, 'road_0_1_0_2': 1, 'road_0_1_0_3': 0, 'road_0_1_0_4': 1, 'road_0_1_0_5': 2, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 2, 'road_1_0_1_2': 0, 'road_1_0_1_3': 1, 'road_1_0_1_4': 1, 'road_1_0_1_5': 1, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 2, 'road_1_2_3_2': 1, 'road_1_2_3_3': 1, 'road_1_2_3_4': 0, 'road_1_2_3_5': 0, 'road_1_2_3_6': 2, 'road_2_1_2_0': 2, 'road_2_1_2_1': 0, 'road_2_1_2_2': 0, 'road_2_1_2_3': 2, 'road_2_1_2_4': 0, 'road_2_1_2_5': 1, 'road_2_1_2_6': 1}
# Time: 10.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 2, 'road_0_1_0_2': 1, 'road_0_1_0_3': 0, 'road_0_1_0_4': 1, 'road_0_1_0_5': 2, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 2, 'road_1_0_1_2': 0, 'road_1_0_1_3': 1, 'road_1_0_1_4': 1, 'road_1_0_1_5': 1, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 2, 'road_1_2_3_2': 1, 'road_1_2_3_3': 1, 'road_1_2_3_4': 0, 'road_1_2_3_5': 0, 'road_1_2_3_6': 2, 'road_2_1_2_0': 2, 'road_2_1_2_1': 0, 'road_2_1_2_2': 0, 'road_2_1_2_3': 2, 'road_2_1_2_4': 0, 'road_2_1_2_5': 1, 'road_2_1_2_6': 1}
# Time: 11.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 3, 'road_0_1_0_2': 1, 'road_0_1_0_3': 1, 'road_0_1_0_4': 1, 'road_0_1_0_5': 3, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 3, 'road_1_0_1_2': 0, 'road_1_0_1_3': 2, 'road_1_0_1_4': 1, 'road_1_0_1_5': 1, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 1, 'road_1_2_3_4': 0, 'road_1_2_3_5': 1, 'road_1_2_3_6': 2, 'road_2_1_2_0': 2, 'road_2_1_2_1': 1, 'road_2_1_2_2': 0, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 1}
# Time: 12.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 3, 'road_0_1_0_2': 1, 'road_0_1_0_3': 1, 'road_0_1_0_4': 1, 'road_0_1_0_5': 3, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 3, 'road_1_0_1_2': 0, 'road_1_0_1_3': 2, 'road_1_0_1_4': 1, 'road_1_0_1_5': 1, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 1, 'road_1_2_3_4': 0, 'road_1_2_3_5': 1, 'road_1_2_3_6': 2, 'road_2_1_2_0': 2, 'road_2_1_2_1': 1, 'road_2_1_2_2': 0, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 1}
# Time: 13.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 3, 'road_0_1_0_2': 1, 'road_0_1_0_3': 1, 'road_0_1_0_4': 1, 'road_0_1_0_5': 3, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 3, 'road_1_0_1_2': 0, 'road_1_0_1_3': 2, 'road_1_0_1_4': 1, 'road_1_0_1_5': 1, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 1, 'road_1_2_3_4': 0, 'road_1_2_3_5': 1, 'road_1_2_3_6': 2, 'road_2_1_2_0': 2, 'road_2_1_2_1': 1, 'road_2_1_2_2': 0, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 1}
# Time: 14.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 3, 'road_0_1_0_2': 1, 'road_0_1_0_3': 1, 'road_0_1_0_4': 1, 'road_0_1_0_5': 3, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 3, 'road_1_0_1_2': 0, 'road_1_0_1_3': 2, 'road_1_0_1_4': 1, 'road_1_0_1_5': 1, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 1, 'road_1_2_3_4': 0, 'road_1_2_3_5': 1, 'road_1_2_3_6': 2, 'road_2_1_2_0': 2, 'road_2_1_2_1': 1, 'road_2_1_2_2': 0, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 1}
# Time: 15.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 0, 'road_0_1_0_1': 3, 'road_0_1_0_2': 1, 'road_0_1_0_3': 1, 'road_0_1_0_4': 1, 'road_0_1_0_5': 3, 'road_0_1_0_6': 0, 'road_1_0_1_0': 0, 'road_1_0_1_1': 3, 'road_1_0_1_2': 0, 'road_1_0_1_3': 2, 'road_1_0_1_4': 1, 'road_1_0_1_5': 1, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 0, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 1, 'road_1_2_3_4': 0, 'road_1_2_3_5': 1, 'road_1_2_3_6': 2, 'road_2_1_2_0': 2, 'road_2_1_2_1': 1, 'road_2_1_2_2': 0, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 1}
# Time: 16.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 3, 'road_0_1_0_2': 1, 'road_0_1_0_3': 2, 'road_0_1_0_4': 1, 'road_0_1_0_5': 4, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 3, 'road_1_0_1_2': 0, 'road_1_0_1_3': 3, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 1, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 2, 'road_1_2_3_4': 0, 'road_1_2_3_5': 2, 'road_1_2_3_6': 2, 'road_2_1_2_0': 3, 'road_2_1_2_1': 1, 'road_2_1_2_2': 1, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 17.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 3, 'road_0_1_0_2': 1, 'road_0_1_0_3': 2, 'road_0_1_0_4': 1, 'road_0_1_0_5': 4, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 3, 'road_1_0_1_2': 0, 'road_1_0_1_3': 3, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 1, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 2, 'road_1_2_3_4': 0, 'road_1_2_3_5': 2, 'road_1_2_3_6': 2, 'road_2_1_2_0': 3, 'road_2_1_2_1': 1, 'road_2_1_2_2': 1, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 18.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 3, 'road_0_1_0_2': 1, 'road_0_1_0_3': 2, 'road_0_1_0_4': 1, 'road_0_1_0_5': 4, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 3, 'road_1_0_1_2': 0, 'road_1_0_1_3': 3, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 1, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 2, 'road_1_2_3_4': 0, 'road_1_2_3_5': 2, 'road_1_2_3_6': 2, 'road_2_1_2_0': 3, 'road_2_1_2_1': 1, 'road_2_1_2_2': 1, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 19.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 3, 'road_0_1_0_2': 1, 'road_0_1_0_3': 2, 'road_0_1_0_4': 1, 'road_0_1_0_5': 4, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 3, 'road_1_0_1_2': 0, 'road_1_0_1_3': 3, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 1, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 2, 'road_1_2_3_4': 0, 'road_1_2_3_5': 2, 'road_1_2_3_6': 2, 'road_2_1_2_0': 3, 'road_2_1_2_1': 1, 'road_2_1_2_2': 1, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 20.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 3, 'road_0_1_0_2': 1, 'road_0_1_0_3': 2, 'road_0_1_0_4': 1, 'road_0_1_0_5': 4, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 3, 'road_1_0_1_2': 0, 'road_1_0_1_3': 3, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 1, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 2, 'road_1_2_3_4': 0, 'road_1_2_3_5': 2, 'road_1_2_3_6': 2, 'road_2_1_2_0': 3, 'road_2_1_2_1': 1, 'road_2_1_2_2': 1, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 21.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 4, 'road_0_1_0_2': 1, 'road_0_1_0_3': 3, 'road_0_1_0_4': 1, 'road_0_1_0_5': 5, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 4, 'road_1_0_1_2': 0, 'road_1_0_1_3': 4, 'road_1_0_1_4': 1, 'road_1_0_1_5': 3, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 2, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 3, 'road_1_2_3_6': 2, 'road_2_1_2_0': 4, 'road_2_1_2_1': 1, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 3}
# Time: 22.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 4, 'road_0_1_0_2': 1, 'road_0_1_0_3': 3, 'road_0_1_0_4': 1, 'road_0_1_0_5': 5, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 4, 'road_1_0_1_2': 0, 'road_1_0_1_3': 4, 'road_1_0_1_4': 1, 'road_1_0_1_5': 3, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 2, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 3, 'road_1_2_3_6': 2, 'road_2_1_2_0': 4, 'road_2_1_2_1': 1, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 3}
# Time: 23.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 4, 'road_0_1_0_2': 1, 'road_0_1_0_3': 3, 'road_0_1_0_4': 1, 'road_0_1_0_5': 4, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 4, 'road_1_0_1_2': 0, 'road_1_0_1_3': 4, 'road_1_0_1_4': 1, 'road_1_0_1_5': 3, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 2, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 4, 'road_2_1_2_1': 1, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 24.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 4, 'road_0_1_0_2': 1, 'road_0_1_0_3': 3, 'road_0_1_0_4': 1, 'road_0_1_0_5': 4, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 4, 'road_1_0_1_2': 0, 'road_1_0_1_3': 4, 'road_1_0_1_4': 1, 'road_1_0_1_5': 3, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 0, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 0, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 0, 'road_1_1_3_6': 0, 'road_1_2_3_0': 2, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 4, 'road_2_1_2_1': 1, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 25.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 4, 'road_0_1_0_2': 1, 'road_0_1_0_3': 3, 'road_0_1_0_4': 1, 'road_0_1_0_5': 4, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 4, 'road_1_0_1_2': 0, 'road_1_0_1_3': 4, 'road_1_0_1_4': 1, 'road_1_0_1_5': 3, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 1, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 1, 'road_1_1_3_6': 0, 'road_1_2_3_0': 2, 'road_1_2_3_1': 3, 'road_1_2_3_2': 2, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 4, 'road_2_1_2_1': 1, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 0, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 26.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 4, 'road_0_1_0_2': 1, 'road_0_1_0_3': 3, 'road_0_1_0_4': 2, 'road_0_1_0_5': 5, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 5, 'road_1_0_1_2': 1, 'road_1_0_1_3': 4, 'road_1_0_1_4': 1, 'road_1_0_1_5': 3, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 1, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 1, 'road_1_1_3_6': 0, 'road_1_2_3_0': 3, 'road_1_2_3_1': 3, 'road_1_2_3_2': 3, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 4, 'road_1_2_3_6': 1, 'road_2_1_2_0': 4, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 1, 'road_2_1_2_5': 3, 'road_2_1_2_6': 2}
# Time: 27.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 4, 'road_0_1_0_2': 1, 'road_0_1_0_3': 3, 'road_0_1_0_4': 2, 'road_0_1_0_5': 5, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 5, 'road_1_0_1_2': 1, 'road_1_0_1_3': 4, 'road_1_0_1_4': 1, 'road_1_0_1_5': 3, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 1, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 1, 'road_1_1_3_6': 0, 'road_1_2_3_0': 3, 'road_1_2_3_1': 3, 'road_1_2_3_2': 3, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 4, 'road_1_2_3_6': 1, 'road_2_1_2_0': 4, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 1, 'road_2_1_2_5': 3, 'road_2_1_2_6': 2}
# Time: 28.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 4, 'road_0_1_0_2': 1, 'road_0_1_0_3': 3, 'road_0_1_0_4': 2, 'road_0_1_0_5': 4, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 5, 'road_1_0_1_2': 1, 'road_1_0_1_3': 4, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 1, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 1, 'road_1_1_3_6': 0, 'road_1_2_3_0': 3, 'road_1_2_3_1': 3, 'road_1_2_3_2': 3, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 4, 'road_1_2_3_6': 0, 'road_2_1_2_0': 4, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 1, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 29.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 4, 'road_0_1_0_2': 1, 'road_0_1_0_3': 3, 'road_0_1_0_4': 2, 'road_0_1_0_5': 4, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 5, 'road_1_0_1_2': 1, 'road_1_0_1_3': 4, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 0, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 1, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 1, 'road_1_1_3_6': 0, 'road_1_2_3_0': 3, 'road_1_2_3_1': 3, 'road_1_2_3_2': 3, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 4, 'road_1_2_3_6': 0, 'road_2_1_2_0': 4, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 1, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 30.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 4, 'road_0_1_0_2': 1, 'road_0_1_0_3': 3, 'road_0_1_0_4': 2, 'road_0_1_0_5': 4, 'road_0_1_0_6': 0, 'road_1_0_1_0': 1, 'road_1_0_1_1': 5, 'road_1_0_1_2': 1, 'road_1_0_1_3': 4, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 1, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 0, 'road_1_2_3_0': 3, 'road_1_2_3_1': 3, 'road_1_2_3_2': 3, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 4, 'road_1_2_3_6': 0, 'road_2_1_2_0': 4, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 1, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 31.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 5, 'road_0_1_0_2': 1, 'road_0_1_0_3': 4, 'road_0_1_0_4': 2, 'road_0_1_0_5': 4, 'road_0_1_0_6': 1, 'road_1_0_1_0': 2, 'road_1_0_1_1': 5, 'road_1_0_1_2': 1, 'road_1_0_1_3': 5, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 3, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 1, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 0, 'road_1_2_3_0': 3, 'road_1_2_3_1': 4, 'road_1_2_3_2': 4, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 4, 'road_1_2_3_6': 1, 'road_2_1_2_0': 5, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 2, 'road_2_1_2_5': 3, 'road_2_1_2_6': 2}
# Time: 32.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 5, 'road_0_1_0_2': 1, 'road_0_1_0_3': 4, 'road_0_1_0_4': 2, 'road_0_1_0_5': 4, 'road_0_1_0_6': 1, 'road_1_0_1_0': 2, 'road_1_0_1_1': 5, 'road_1_0_1_2': 1, 'road_1_0_1_3': 5, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 3, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 1, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 0, 'road_1_2_3_0': 3, 'road_1_2_3_1': 4, 'road_1_2_3_2': 4, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 4, 'road_1_2_3_6': 1, 'road_2_1_2_0': 5, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 2, 'road_2_1_2_5': 3, 'road_2_1_2_6': 2}
# Time: 33.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 5, 'road_0_1_0_2': 1, 'road_0_1_0_3': 4, 'road_0_1_0_4': 2, 'road_0_1_0_5': 3, 'road_0_1_0_6': 1, 'road_1_0_1_0': 2, 'road_1_0_1_1': 5, 'road_1_0_1_2': 1, 'road_1_0_1_3': 5, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 1, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 0, 'road_1_2_3_0': 3, 'road_1_2_3_1': 4, 'road_1_2_3_2': 4, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 5, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 2, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 34.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 5, 'road_0_1_0_2': 1, 'road_0_1_0_3': 4, 'road_0_1_0_4': 2, 'road_0_1_0_5': 3, 'road_0_1_0_6': 1, 'road_1_0_1_0': 2, 'road_1_0_1_1': 5, 'road_1_0_1_2': 1, 'road_1_0_1_3': 5, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 1, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 0, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 0, 'road_1_2_3_0': 3, 'road_1_2_3_1': 4, 'road_1_2_3_2': 4, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 5, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 2, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 35.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 5, 'road_0_1_0_2': 1, 'road_0_1_0_3': 4, 'road_0_1_0_4': 2, 'road_0_1_0_5': 3, 'road_0_1_0_6': 1, 'road_1_0_1_0': 2, 'road_1_0_1_1': 5, 'road_1_0_1_2': 1, 'road_1_0_1_3': 5, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 1, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 2, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 1, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 3, 'road_1_1_3_6': 0, 'road_1_2_3_0': 3, 'road_1_2_3_1': 4, 'road_1_2_3_2': 4, 'road_1_2_3_3': 2, 'road_1_2_3_4': 1, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 5, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 2, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 36.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 6, 'road_0_1_0_2': 1, 'road_0_1_0_3': 5, 'road_0_1_0_4': 2, 'road_0_1_0_5': 3, 'road_0_1_0_6': 2, 'road_1_0_1_0': 2, 'road_1_0_1_1': 6, 'road_1_0_1_2': 1, 'road_1_0_1_3': 6, 'road_1_0_1_4': 1, 'road_1_0_1_5': 3, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 1, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 2, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 1, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 3, 'road_1_1_3_6': 0, 'road_1_2_3_0': 4, 'road_1_2_3_1': 4, 'road_1_2_3_2': 4, 'road_1_2_3_3': 2, 'road_1_2_3_4': 2, 'road_1_2_3_5': 4, 'road_1_2_3_6': 1, 'road_2_1_2_0': 6, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 3, 'road_2_1_2_5': 3, 'road_2_1_2_6': 2}
# Time: 37.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 6, 'road_0_1_0_2': 1, 'road_0_1_0_3': 5, 'road_0_1_0_4': 2, 'road_0_1_0_5': 3, 'road_0_1_0_6': 2, 'road_1_0_1_0': 2, 'road_1_0_1_1': 6, 'road_1_0_1_2': 1, 'road_1_0_1_3': 6, 'road_1_0_1_4': 1, 'road_1_0_1_5': 3, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 1, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 2, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 1, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 3, 'road_1_1_3_6': 0, 'road_1_2_3_0': 4, 'road_1_2_3_1': 4, 'road_1_2_3_2': 4, 'road_1_2_3_3': 2, 'road_1_2_3_4': 2, 'road_1_2_3_5': 4, 'road_1_2_3_6': 1, 'road_2_1_2_0': 6, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 3, 'road_2_1_2_5': 3, 'road_2_1_2_6': 2}
# Time: 38.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 6, 'road_0_1_0_2': 1, 'road_0_1_0_3': 5, 'road_0_1_0_4': 2, 'road_0_1_0_5': 2, 'road_0_1_0_6': 2, 'road_1_0_1_0': 2, 'road_1_0_1_1': 6, 'road_1_0_1_2': 1, 'road_1_0_1_3': 6, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 1, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 2, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 1, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 3, 'road_1_1_3_6': 0, 'road_1_2_3_0': 4, 'road_1_2_3_1': 4, 'road_1_2_3_2': 4, 'road_1_2_3_3': 2, 'road_1_2_3_4': 2, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 6, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 3, 'road_2_1_2_5': 3, 'road_2_1_2_6': 1}
# Time: 39.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 2, 'road_0_1_0_1': 6, 'road_0_1_0_2': 1, 'road_0_1_0_3': 5, 'road_0_1_0_4': 2, 'road_0_1_0_5': 2, 'road_0_1_0_6': 2, 'road_1_0_1_0': 2, 'road_1_0_1_1': 6, 'road_1_0_1_2': 1, 'road_1_0_1_3': 6, 'road_1_0_1_4': 1, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 1, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 2, 'road_1_1_1_6': 1, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 1, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 3, 'road_1_1_3_6': 0, 'road_1_2_3_0': 4, 'road_1_2_3_1': 4, 'road_1_2_3_2': 4, 'road_1_2_3_3': 2, 'road_1_2_3_4': 2, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 6, 'road_2_1_2_1': 2, 'road_2_1_2_2': 2, 'road_2_1_2_3': 3, 'road_2_1_2_4': 3, 'road_2_1_2_5': 3, 'road_2_1_2_6': 1}
# Time: 45.0, Phase: 2, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 6, 'road_0_1_0_2': 0, 'road_0_1_0_3': 3, 'road_0_1_0_4': 2, 'road_0_1_0_5': 1, 'road_0_1_0_6': 3, 'road_1_0_1_0': 2, 'road_1_0_1_1': 7, 'road_1_0_1_2': 2, 'road_1_0_1_3': 6, 'road_1_0_1_4': 1, 'road_1_0_1_5': 1, 'road_1_0_1_6': 3, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 3, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 2, 'road_1_1_1_6': 2, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 3, 'road_1_1_2_6': 1, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 4, 'road_1_1_3_6': 0, 'road_1_2_3_0': 5, 'road_1_2_3_1': 4, 'road_1_2_3_2': 4, 'road_1_2_3_3': 3, 'road_1_2_3_4': 2, 'road_1_2_3_5': 2, 'road_1_2_3_6': 2, 'road_2_1_2_0': 5, 'road_2_1_2_1': 2, 'road_2_1_2_2': 0, 'road_2_1_2_3': 2, 'road_2_1_2_4': 3, 'road_2_1_2_5': 3, 'road_2_1_2_6': 1}
# Time: 46.0, Phase: 2, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 7, 'road_0_1_0_2': 0, 'road_0_1_0_3': 4, 'road_0_1_0_4': 1, 'road_0_1_0_5': 2, 'road_0_1_0_6': 3, 'road_1_0_1_0': 2, 'road_1_0_1_1': 8, 'road_1_0_1_2': 2, 'road_1_0_1_3': 6, 'road_1_0_1_4': 2, 'road_1_0_1_5': 2, 'road_1_0_1_6': 3, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 3, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 2, 'road_1_1_1_6': 2, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 3, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 4, 'road_1_1_3_6': 0, 'road_1_2_3_0': 5, 'road_1_2_3_1': 5, 'road_1_2_3_2': 4, 'road_1_2_3_3': 3, 'road_1_2_3_4': 3, 'road_1_2_3_5': 2, 'road_1_2_3_6': 3, 'road_2_1_2_0': 6, 'road_2_1_2_1': 2, 'road_2_1_2_2': 0, 'road_2_1_2_3': 3, 'road_2_1_2_4': 2, 'road_2_1_2_5': 4, 'road_2_1_2_6': 1}
# Time: 47.0, Phase: 2, lane_vehicle_count: {'road_0_1_0_0': 1, 'road_0_1_0_1': 7, 'road_0_1_0_2': 0, 'road_0_1_0_3': 4, 'road_0_1_0_4': 1, 'road_0_1_0_5': 2, 'road_0_1_0_6': 3, 'road_1_0_1_0': 2, 'road_1_0_1_1': 8, 'road_1_0_1_2': 2, 'road_1_0_1_3': 6, 'road_1_0_1_4': 2, 'road_1_0_1_5': 2, 'road_1_0_1_6': 3, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 1, 'road_1_1_0_3': 1, 'road_1_1_0_4': 1, 'road_1_1_0_5': 2, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 2, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 1, 'road_1_1_2_3': 1, 'road_1_1_2_4': 0, 'road_1_1_2_5': 3, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 3, 'road_1_1_3_6': 0, 'road_1_2_3_0': 5, 'road_1_2_3_1': 5, 'road_1_2_3_2': 4, 'road_1_2_3_3': 3, 'road_1_2_3_4': 3, 'road_1_2_3_5': 2, 'road_1_2_3_6': 3, 'road_2_1_2_0': 6, 'road_2_1_2_1': 2, 'road_2_1_2_2': 0, 'road_2_1_2_3': 3, 'road_2_1_2_4': 2, 'road_2_1_2_5': 4, 'road_2_1_2_6': 1}
# ...
# Time: 181.0, Phase: 7, lane_vehicle_count: {'road_0_1_0_0': 13, 'road_0_1_0_1': 15, 'road_0_1_0_2': 1, 'road_0_1_0_3': 6, 'road_0_1_0_4': 1, 'road_0_1_0_5': 4, 'road_0_1_0_6': 1, 'road_1_0_1_0': 11, 'road_1_0_1_1': 10, 'road_1_0_1_2': 5, 'road_1_0_1_3': 9, 'road_1_0_1_4': 4, 'road_1_0_1_5': 3, 'road_1_0_1_6': 2, 'road_1_1_0_0': 1, 'road_1_1_0_1': 2, 'road_1_1_0_2': 1, 'road_1_1_0_3': 2, 'road_1_1_0_4': 2, 'road_1_1_0_5': 2, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 3, 'road_1_1_2_0': 1, 'road_1_1_2_1': 2, 'road_1_1_2_2': 2, 'road_1_1_2_3': 0, 'road_1_1_2_4': 2, 'road_1_1_2_5': 4, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 1, 'road_1_2_3_0': 11, 'road_1_2_3_1': 10, 'road_1_2_3_2': 6, 'road_1_2_3_3': 5, 'road_1_2_3_4': 6, 'road_1_2_3_5': 3, 'road_1_2_3_6': 2, 'road_2_1_2_0': 17, 'road_2_1_2_1': 11, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 8, 'road_2_1_2_5': 2, 'road_2_1_2_6': 3}
# Time: 182.0, Phase: 7, lane_vehicle_count: {'road_0_1_0_0': 13, 'road_0_1_0_1': 15, 'road_0_1_0_2': 1, 'road_0_1_0_3': 6, 'road_0_1_0_4': 1, 'road_0_1_0_5': 4, 'road_0_1_0_6': 1, 'road_1_0_1_0': 11, 'road_1_0_1_1': 10, 'road_1_0_1_2': 5, 'road_1_0_1_3': 9, 'road_1_0_1_4': 4, 'road_1_0_1_5': 3, 'road_1_0_1_6': 2, 'road_1_1_0_0': 1, 'road_1_1_0_1': 1, 'road_1_1_0_2': 1, 'road_1_1_0_3': 2, 'road_1_1_0_4': 2, 'road_1_1_0_5': 1, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 3, 'road_1_1_2_0': 1, 'road_1_1_2_1': 1, 'road_1_1_2_2': 2, 'road_1_1_2_3': 0, 'road_1_1_2_4': 2, 'road_1_1_2_5': 3, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 1, 'road_1_2_3_0': 11, 'road_1_2_3_1': 10, 'road_1_2_3_2': 6, 'road_1_2_3_3': 5, 'road_1_2_3_4': 6, 'road_1_2_3_5': 3, 'road_1_2_3_6': 2, 'road_2_1_2_0': 17, 'road_2_1_2_1': 11, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 8, 'road_2_1_2_5': 2, 'road_2_1_2_6': 3}
# Time: 183.0, Phase: 7, lane_vehicle_count: {'road_0_1_0_0': 13, 'road_0_1_0_1': 15, 'road_0_1_0_2': 1, 'road_0_1_0_3': 6, 'road_0_1_0_4': 1, 'road_0_1_0_5': 3, 'road_0_1_0_6': 1, 'road_1_0_1_0': 11, 'road_1_0_1_1': 10, 'road_1_0_1_2': 5, 'road_1_0_1_3': 9, 'road_1_0_1_4': 4, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 1, 'road_1_1_0_2': 1, 'road_1_1_0_3': 2, 'road_1_1_0_4': 2, 'road_1_1_0_5': 1, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 3, 'road_1_1_2_0': 0, 'road_1_1_2_1': 1, 'road_1_1_2_2': 2, 'road_1_1_2_3': 0, 'road_1_1_2_4': 2, 'road_1_1_2_5': 3, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 1, 'road_1_2_3_0': 11, 'road_1_2_3_1': 10, 'road_1_2_3_2': 6, 'road_1_2_3_3': 5, 'road_1_2_3_4': 6, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 17, 'road_2_1_2_1': 11, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 8, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 184.0, Phase: 7, lane_vehicle_count: {'road_0_1_0_0': 13, 'road_0_1_0_1': 15, 'road_0_1_0_2': 1, 'road_0_1_0_3': 6, 'road_0_1_0_4': 1, 'road_0_1_0_5': 3, 'road_0_1_0_6': 1, 'road_1_0_1_0': 11, 'road_1_0_1_1': 10, 'road_1_0_1_2': 5, 'road_1_0_1_3': 9, 'road_1_0_1_4': 4, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 1, 'road_1_1_0_3': 2, 'road_1_1_0_4': 2, 'road_1_1_0_5': 1, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 3, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 2, 'road_1_1_2_3': 0, 'road_1_1_2_4': 2, 'road_1_1_2_5': 3, 'road_1_1_2_6': 0, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 1, 'road_1_2_3_0': 11, 'road_1_2_3_1': 10, 'road_1_2_3_2': 6, 'road_1_2_3_3': 5, 'road_1_2_3_4': 6, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 17, 'road_2_1_2_1': 11, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 8, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 185.0, Phase: 7, lane_vehicle_count: {'road_0_1_0_0': 13, 'road_0_1_0_1': 15, 'road_0_1_0_2': 1, 'road_0_1_0_3': 6, 'road_0_1_0_4': 1, 'road_0_1_0_5': 3, 'road_0_1_0_6': 1, 'road_1_0_1_0': 11, 'road_1_0_1_1': 10, 'road_1_0_1_2': 5, 'road_1_0_1_3': 9, 'road_1_0_1_4': 4, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 1, 'road_1_1_0_3': 2, 'road_1_1_0_4': 2, 'road_1_1_0_5': 2, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 4, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 2, 'road_1_1_2_3': 0, 'road_1_1_2_4': 2, 'road_1_1_2_5': 3, 'road_1_1_2_6': 1, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 3, 'road_1_1_3_6': 1, 'road_1_2_3_0': 11, 'road_1_2_3_1': 10, 'road_1_2_3_2': 6, 'road_1_2_3_3': 5, 'road_1_2_3_4': 6, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 17, 'road_2_1_2_1': 11, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 8, 'road_2_1_2_5': 2, 'road_2_1_2_6': 2}
# Time: 186.0, Phase: 7, lane_vehicle_count: {'road_0_1_0_0': 13, 'road_0_1_0_1': 16, 'road_0_1_0_2': 1, 'road_0_1_0_3': 6, 'road_0_1_0_4': 2, 'road_0_1_0_5': 4, 'road_0_1_0_6': 1, 'road_1_0_1_0': 11, 'road_1_0_1_1': 11, 'road_1_0_1_2': 5, 'road_1_0_1_3': 10, 'road_1_0_1_4': 4, 'road_1_0_1_5': 3, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 1, 'road_1_1_0_3': 2, 'road_1_1_0_4': 2, 'road_1_1_0_5': 2, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 3, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 2, 'road_1_1_2_3': 0, 'road_1_1_2_4': 2, 'road_1_1_2_5': 3, 'road_1_1_2_6': 1, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 3, 'road_1_1_3_6': 1, 'road_1_2_3_0': 12, 'road_1_2_3_1': 10, 'road_1_2_3_2': 6, 'road_1_2_3_3': 5, 'road_1_2_3_4': 7, 'road_1_2_3_5': 4, 'road_1_2_3_6': 1, 'road_2_1_2_0': 18, 'road_2_1_2_1': 11, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 9, 'road_2_1_2_5': 2, 'road_2_1_2_6': 3}
# Time: 187.0, Phase: 7, lane_vehicle_count: {'road_0_1_0_0': 13, 'road_0_1_0_1': 16, 'road_0_1_0_2': 1, 'road_0_1_0_3': 6, 'road_0_1_0_4': 2, 'road_0_1_0_5': 4, 'road_0_1_0_6': 1, 'road_1_0_1_0': 11, 'road_1_0_1_1': 11, 'road_1_0_1_2': 5, 'road_1_0_1_3': 10, 'road_1_0_1_4': 4, 'road_1_0_1_5': 3, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 2, 'road_1_1_0_4': 2, 'road_1_1_0_5': 1, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 3, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 2, 'road_1_1_2_3': 0, 'road_1_1_2_4': 2, 'road_1_1_2_5': 2, 'road_1_1_2_6': 1, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 1, 'road_1_2_3_0': 12, 'road_1_2_3_1': 10, 'road_1_2_3_2': 6, 'road_1_2_3_3': 5, 'road_1_2_3_4': 7, 'road_1_2_3_5': 4, 'road_1_2_3_6': 1, 'road_2_1_2_0': 18, 'road_2_1_2_1': 11, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 9, 'road_2_1_2_5': 2, 'road_2_1_2_6': 3}
# Time: 188.0, Phase: 7, lane_vehicle_count: {'road_0_1_0_0': 13, 'road_0_1_0_1': 16, 'road_0_1_0_2': 1, 'road_0_1_0_3': 6, 'road_0_1_0_4': 2, 'road_0_1_0_5': 3, 'road_0_1_0_6': 1, 'road_1_0_1_0': 11, 'road_1_0_1_1': 11, 'road_1_0_1_2': 5, 'road_1_0_1_3': 10, 'road_1_0_1_4': 4, 'road_1_0_1_5': 3, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 2, 'road_1_1_0_4': 1, 'road_1_1_0_5': 1, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 3, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 2, 'road_1_1_2_3': 0, 'road_1_1_2_4': 2, 'road_1_1_2_5': 2, 'road_1_1_2_6': 1, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 1, 'road_1_2_3_0': 12, 'road_1_2_3_1': 10, 'road_1_2_3_2': 6, 'road_1_2_3_3': 5, 'road_1_2_3_4': 7, 'road_1_2_3_5': 4, 'road_1_2_3_6': 0, 'road_2_1_2_0': 18, 'road_2_1_2_1': 11, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 9, 'road_2_1_2_5': 1, 'road_2_1_2_6': 3}
# Time: 189.0, Phase: 7, lane_vehicle_count: {'road_0_1_0_0': 13, 'road_0_1_0_1': 16, 'road_0_1_0_2': 1, 'road_0_1_0_3': 6, 'road_0_1_0_4': 2, 'road_0_1_0_5': 3, 'road_0_1_0_6': 1, 'road_1_0_1_0': 11, 'road_1_0_1_1': 11, 'road_1_0_1_2': 5, 'road_1_0_1_3': 10, 'road_1_0_1_4': 4, 'road_1_0_1_5': 3, 'road_1_0_1_6': 1, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 1, 'road_1_1_0_4': 1, 'road_1_1_0_5': 1, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 0, 'road_1_1_1_6': 3, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 1, 'road_1_1_2_3': 0, 'road_1_1_2_4': 1, 'road_1_1_2_5': 2, 'road_1_1_2_6': 1, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 1, 'road_1_2_3_0': 12, 'road_1_2_3_1': 10, 'road_1_2_3_2': 6, 'road_1_2_3_3': 5, 'road_1_2_3_4': 7, 'road_1_2_3_5': 4, 'road_1_2_3_6': 0, 'road_2_1_2_0': 18, 'road_2_1_2_1': 11, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 9, 'road_2_1_2_5': 1, 'road_2_1_2_6': 3}
# Time: 195.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 14, 'road_0_1_0_1': 16, 'road_0_1_0_2': 0, 'road_0_1_0_3': 5, 'road_0_1_0_4': 1, 'road_0_1_0_5': 3, 'road_0_1_0_6': 1, 'road_1_0_1_0': 12, 'road_1_0_1_1': 11, 'road_1_0_1_2': 5, 'road_1_0_1_3': 10, 'road_1_0_1_4': 5, 'road_1_0_1_5': 2, 'road_1_0_1_6': 2, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 2, 'road_1_1_0_6': 2, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 3, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 2, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 3, 'road_1_1_3_6': 1, 'road_1_2_3_0': 12, 'road_1_2_3_1': 11, 'road_1_2_3_2': 6, 'road_1_2_3_3': 6, 'road_1_2_3_4': 7, 'road_1_2_3_5': 4, 'road_1_2_3_6': 0, 'road_2_1_2_0': 19, 'road_2_1_2_1': 11, 'road_2_1_2_2': 2, 'road_2_1_2_3': 0, 'road_2_1_2_4': 7, 'road_2_1_2_5': 1, 'road_2_1_2_6': 3}
# Time: 196.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 14, 'road_0_1_0_1': 17, 'road_0_1_0_2': 0, 'road_0_1_0_3': 5, 'road_0_1_0_4': 2, 'road_0_1_0_5': 4, 'road_0_1_0_6': 1, 'road_1_0_1_0': 13, 'road_1_0_1_1': 11, 'road_1_0_1_2': 5, 'road_1_0_1_3': 10, 'road_1_0_1_4': 6, 'road_1_0_1_5': 2, 'road_1_0_1_6': 3, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 0, 'road_1_1_0_3': 0, 'road_1_1_0_4': 0, 'road_1_1_0_5': 2, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 2, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 0, 'road_1_1_2_3': 0, 'road_1_1_2_4': 0, 'road_1_1_2_5': 2, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 3, 'road_1_1_3_6': 1, 'road_1_2_3_0': 12, 'road_1_2_3_1': 12, 'road_1_2_3_2': 6, 'road_1_2_3_3': 6, 'road_1_2_3_4': 8, 'road_1_2_3_5': 4, 'road_1_2_3_6': 1, 'road_2_1_2_0': 19, 'road_2_1_2_1': 12, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 7, 'road_2_1_2_5': 1, 'road_2_1_2_6': 4}
# Time: 197.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 14, 'road_0_1_0_1': 17, 'road_0_1_0_2': 0, 'road_0_1_0_3': 5, 'road_0_1_0_4': 2, 'road_0_1_0_5': 4, 'road_0_1_0_6': 1, 'road_1_0_1_0': 13, 'road_1_0_1_1': 11, 'road_1_0_1_2': 5, 'road_1_0_1_3': 10, 'road_1_0_1_4': 6, 'road_1_0_1_5': 2, 'road_1_0_1_6': 3, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 1, 'road_1_1_0_3': 1, 'road_1_1_0_4': 1, 'road_1_1_0_5': 2, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 2, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 1, 'road_1_1_2_3': 0, 'road_1_1_2_4': 1, 'road_1_1_2_5': 1, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 1, 'road_1_2_3_0': 12, 'road_1_2_3_1': 12, 'road_1_2_3_2': 6, 'road_1_2_3_3': 6, 'road_1_2_3_4': 8, 'road_1_2_3_5': 4, 'road_1_2_3_6': 1, 'road_2_1_2_0': 19, 'road_2_1_2_1': 12, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 7, 'road_2_1_2_5': 1, 'road_2_1_2_6': 4}
# Time: 198.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 14, 'road_0_1_0_1': 17, 'road_0_1_0_2': 0, 'road_0_1_0_3': 5, 'road_0_1_0_4': 2, 'road_0_1_0_5': 3, 'road_0_1_0_6': 1, 'road_1_0_1_0': 13, 'road_1_0_1_1': 11, 'road_1_0_1_2': 5, 'road_1_0_1_3': 10, 'road_1_0_1_4': 6, 'road_1_0_1_5': 1, 'road_1_0_1_6': 3, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 1, 'road_1_1_0_3': 1, 'road_1_1_0_4': 1, 'road_1_1_0_5': 2, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 2, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 1, 'road_1_1_2_3': 0, 'road_1_1_2_4': 1, 'road_1_1_2_5': 1, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 1, 'road_1_2_3_0': 12, 'road_1_2_3_1': 12, 'road_1_2_3_2': 6, 'road_1_2_3_3': 6, 'road_1_2_3_4': 8, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 19, 'road_2_1_2_1': 12, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 7, 'road_2_1_2_5': 0, 'road_2_1_2_6': 4}
# Time: 199.0, Phase: 1, lane_vehicle_count: {'road_0_1_0_0': 14, 'road_0_1_0_1': 17, 'road_0_1_0_2': 0, 'road_0_1_0_3': 5, 'road_0_1_0_4': 2, 'road_0_1_0_5': 3, 'road_0_1_0_6': 1, 'road_1_0_1_0': 13, 'road_1_0_1_1': 11, 'road_1_0_1_2': 5, 'road_1_0_1_3': 10, 'road_1_0_1_4': 6, 'road_1_0_1_5': 1, 'road_1_0_1_6': 3, 'road_1_1_0_0': 0, 'road_1_1_0_1': 0, 'road_1_1_0_2': 1, 'road_1_1_0_3': 2, 'road_1_1_0_4': 1, 'road_1_1_0_5': 2, 'road_1_1_0_6': 1, 'road_1_1_1_0': 0, 'road_1_1_1_1': 0, 'road_1_1_1_2': 0, 'road_1_1_1_3': 0, 'road_1_1_1_4': 0, 'road_1_1_1_5': 1, 'road_1_1_1_6': 2, 'road_1_1_2_0': 0, 'road_1_1_2_1': 0, 'road_1_1_2_2': 2, 'road_1_1_2_3': 0, 'road_1_1_2_4': 2, 'road_1_1_2_5': 1, 'road_1_1_2_6': 2, 'road_1_1_3_0': 0, 'road_1_1_3_1': 0, 'road_1_1_3_2': 0, 'road_1_1_3_3': 0, 'road_1_1_3_4': 0, 'road_1_1_3_5': 2, 'road_1_1_3_6': 1, 'road_1_2_3_0': 12, 'road_1_2_3_1': 12, 'road_1_2_3_2': 6, 'road_1_2_3_3': 6, 'road_1_2_3_4': 8, 'road_1_2_3_5': 3, 'road_1_2_3_6': 1, 'road_2_1_2_0': 19, 'road_2_1_2_1': 12, 'road_2_1_2_2': 3, 'road_2_1_2_3': 0, 'road_2_1_2_4': 7, 'road_2_1_2_5': 0, 'road_2_1_2_6': 4}
